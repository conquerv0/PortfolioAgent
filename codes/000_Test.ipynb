# %%
import numpy as np
import pandas as pd
from google.colab import drive

def generate_and_save_random_data(filepath):
  # Generate random data
  data = np.random.rand(1000, 3)

  # Create a Pandas DataFrame
  df = pd.DataFrame(data, columns=['Column1', 'Column2', 'Column3'])

  # Save the DataFrame to a CSV file in Google Drive
  df.to_csv(filepath, index=False)

  print(df)


# Set the file path
filepath = '/content/drive/My Drive/MS Finance Thesis Shared Drive/data/test_data.csv'

# Example usage (replace with your desired file path)
drive.mount('/content/drive')
generate_and_save_random_data(filepath)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#       Column1   Column2   Column3
# 0    0.814027  0.851337  0.431137
# 1    0.303456  0.476659  0.911265
# 2    0.060063  0.596794  0.337510
# 3    0.281827  0.617470  0.404125
# 4    0.308073  0.925454  0.722057
# ..        ...       ...       ...
# 995  0.104826  0.982724  0.380656
# 996  0.879424  0.410239  0.290568
# 997  0.707691  0.469262  0.712450
# 998  0.162627  0.691523  0.767024
# 999  0.287210  0.877872  0.802550
#
# [1000 rows x 3 columns]

# %%
# Load the data
df = pd.read_csv(filepath)

# Print the DataFrame
df
# Out:
#       Column1   Column2   Column3
# 0    0.814027  0.851337  0.431137
# 1    0.303456  0.476659  0.911265
# 2    0.060063  0.596794  0.337510
# 3    0.281827  0.617470  0.404125
# 4    0.308073  0.925454  0.722057
# ..        ...       ...       ...
# 995  0.104826  0.982724  0.380656
# 996  0.879424  0.410239  0.290568
# 997  0.707691  0.469262  0.712450
# 998  0.162627  0.691523  0.767024
# 999  0.287210  0.877872  0.802550
#
# [1000 rows x 3 columns]
